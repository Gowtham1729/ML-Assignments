# %% [markdown]
# # Q5

# %% [markdown]
# ** a) Algorithm for randomly choosing random values **

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import time

# %%
l = np.zeros(100)
c = []
def random(n):
    time.sleep(0.001)
    return(int(time.time()*1000)%100)

# %% [markdown]
# **  b) Random values from 0 to 100 (1000 times) **

# %%
for i in range(1000):
    time.sleep(0.002)
    num = random(100)
    l[num] = l[num]+1
plt.plot(range(1, 101), l)
plt.figure(figsize=(20, 8))
plt.show()

# %%
l
# Out:
# array([ 9., 11.,  9.,  8., 11., 11.,  9., 10., 11.,  6., 12., 11.,  7.,
#        10., 11., 11.,  8., 10.,  9., 10.,  9., 10., 11.,  8., 14.,  9.,
#         9., 10., 11., 10.,  9.,  9., 12.,  9.,  8., 14.,  8., 10., 14.,
#         6., 11., 13.,  8.,  9., 10., 13.,  8., 10., 13.,  9.,  8., 14.,
#         7., 11., 11.,  9.,  8., 10., 15.,  7.,  9., 13.,  9.,  9., 14.,
#         8., 10., 12.,  8.,  9., 12., 11.,  8., 11., 10.,  8., 11., 13.,
#         7., 11., 10., 11.,  9.,  9., 12.,  7., 13.,  6., 11., 13.,  8.,
#         9.,  9., 11., 10., 10., 10., 10., 12.,  9.])
